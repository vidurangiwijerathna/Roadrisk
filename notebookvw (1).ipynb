# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df_train = pd.read_csv("/kaggle/input/playground-series-s5e10/train.csv")
df_test  = pd.read_csv("/kaggle/input/playground-series-s5e10/test.csv")

# %%
df_train.head(10)
# Out:
#    id road_type  num_lanes  curvature  speed_limit  lighting weather  \
# 0   0     urban          2       0.06           35  daylight   rainy
# 1   1     urban          4       0.99           35  daylight   clear
# 2   2     rural          4       0.63           70       dim   clear
# 3   3   highway          4       0.07           35       dim   rainy
# 4   4     rural          1       0.58           60  daylight   foggy
# 5   5   highway          3       0.54           70     night   foggy
# 6   6   highway          1       0.04           45     night   foggy
# 7   7   highway          2       0.33           45  daylight   clear
# 8   8     rural          3       0.63           25       dim   clear
# 9   9     urban          4       0.38           45       dim   clear
#
#    road_signs_present  public_road time_of_day  holiday  school_season  \
# 0               False         True   afternoon    False           True
# 1                True        False     evening     True           True
# 2               False         True     morning     True          False
# 3                True         True     morning    False          False
# 4               False        False     evening     True          False
# 5                True        False     morning    False           True
# 6               False         True     morning     True          False
# 7               False         True     evening    False           True
# 8                True        False     evening     True           True
# 9                True         True   afternoon     True           True
#
#    num_reported_accidents  accident_risk
# 0                       1           0.13
# 1                       0           0.35
# 2                       2           0.30
# 3                       1           0.21
# 4                       1           0.56
# 5                       0           0.61
# 6                       2           0.20
# 7                       0           0.16
# 8                       2           0.18
# 9                       2           0.15

# %%
df_test.head()
# Out:
#        id road_type  num_lanes  curvature  speed_limit  lighting weather  \
# 0  517754   highway          2       0.34           45     night   clear
# 1  517755     urban          3       0.04           45       dim   foggy
# 2  517756     urban          2       0.59           35       dim   clear
# 3  517757     rural          4       0.95           35  daylight   rainy
# 4  517758   highway          2       0.86           35  daylight   clear
#
#    road_signs_present  public_road time_of_day  holiday  school_season  \
# 0                True         True   afternoon     True           True
# 1                True        False   afternoon     True          False
# 2                True        False   afternoon     True           True
# 3               False        False   afternoon    False          False
# 4                True        False     evening    False           True
#
#    num_reported_accidents
# 0                       1
# 1                       0
# 2                       1
# 3                       2
# 4                       3

# %%
df_train.shape
# Out:
# (517754, 14)

# %%
df_test.shape
# Out:
# (172585, 13)

# %%
df_train.columns
# Out:
# Index(['id', 'road_type', 'num_lanes', 'curvature', 'speed_limit', 'lighting',
#        'weather', 'road_signs_present', 'public_road', 'time_of_day',
#        'holiday', 'school_season', 'num_reported_accidents', 'accident_risk'],
#       dtype='object')

# %%
df_test.columns
# Out:
# Index(['id', 'road_type', 'num_lanes', 'curvature', 'speed_limit', 'lighting',
#        'weather', 'road_signs_present', 'public_road', 'time_of_day',
#        'holiday', 'school_season', 'num_reported_accidents'],
#       dtype='object')

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517754 entries, 0 to 517753
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   id                      517754 non-null  int64
#  1   road_type               517754 non-null  object
#  2   num_lanes               517754 non-null  int64
#  3   curvature               517754 non-null  float64
#  4   speed_limit             517754 non-null  int64
#  5   lighting                517754 non-null  object
#  6   weather                 517754 non-null  object
#  7   road_signs_present      517754 non-null  bool
#  8   public_road             517754 non-null  bool
#  9   time_of_day             517754 non-null  object
#  10  holiday                 517754 non-null  bool
#  11  school_season           517754 non-null  bool
#  12  num_reported_accidents  517754 non-null  int64
#  13  accident_risk           517754 non-null  float64
# dtypes: bool(4), float64(2), int64(4), object(4)
# memory usage: 41.5+ MB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172585 entries, 0 to 172584
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   id                      172585 non-null  int64
#  1   road_type               172585 non-null  object
#  2   num_lanes               172585 non-null  int64
#  3   curvature               172585 non-null  float64
#  4   speed_limit             172585 non-null  int64
#  5   lighting                172585 non-null  object
#  6   weather                 172585 non-null  object
#  7   road_signs_present      172585 non-null  bool
#  8   public_road             172585 non-null  bool
#  9   time_of_day             172585 non-null  object
#  10  holiday                 172585 non-null  bool
#  11  school_season           172585 non-null  bool
#  12  num_reported_accidents  172585 non-null  int64
# dtypes: bool(4), float64(1), int64(4), object(4)
# memory usage: 12.5+ MB

# %%
df_train.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_test.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_train.isnull().sum()
# Out:
# id                        0
# road_type                 0
# num_lanes                 0
# curvature                 0
# speed_limit               0
# lighting                  0
# weather                   0
# road_signs_present        0
# public_road               0
# time_of_day               0
# holiday                   0
# school_season             0
# num_reported_accidents    0
# accident_risk             0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# id                        0
# road_type                 0
# num_lanes                 0
# curvature                 0
# speed_limit               0
# lighting                  0
# weather                   0
# road_signs_present        0
# public_road               0
# time_of_day               0
# holiday                   0
# school_season             0
# num_reported_accidents    0
# dtype: int64

# %%
df_train.isnull()
# Out:
#            id  road_type  num_lanes  curvature  speed_limit  lighting  \
# 0       False      False      False      False        False     False
# 1       False      False      False      False        False     False
# 2       False      False      False      False        False     False
# 3       False      False      False      False        False     False
# 4       False      False      False      False        False     False
# ...       ...        ...        ...        ...          ...       ...
# 517749  False      False      False      False        False     False
# 517750  False      False      False      False        False     False
# 517751  False      False      False      False        False     False
# 517752  False      False      False      False        False     False
# 517753  False      False      False      False        False     False
#
#         weather  road_signs_present  public_road  time_of_day  holiday  \
# 0         False               False        False        False    False
# 1         False               False        False        False    False
# 2         False               False        False        False    False
# 3         False               False        False        False    False
# 4         False               False        False        False    False
# ...         ...                 ...          ...          ...      ...
# 517749    False               False        False        False    False
# 517750    False               False        False        False    False
# 517751    False               False        False        False    False
# 517752    False               False        False        False    False
# 517753    False               False        False        False    False
#
#         school_season  num_reported_accidents  accident_risk
# 0               False                   False          False
# 1               False                   False          False
# 2               False                   False          False
# 3               False                   False          False
# 4               False                   False          False
# ...               ...                     ...            ...
# 517749          False                   False          False
# 517750          False                   False          False
# 517751          False                   False          False
# 517752          False                   False          False
# 517753          False                   False          False
#
# [517754 rows x 14 columns]

# %%
df_train.describe()
# Out:
#                   id      num_lanes      curvature    speed_limit  \
# count  517754.000000  517754.000000  517754.000000  517754.000000
# mean   258876.500000       2.491511       0.488719      46.112575
# std    149462.849974       1.120434       0.272563      15.788521
# min         0.000000       1.000000       0.000000      25.000000
# 25%    129438.250000       1.000000       0.260000      35.000000
# 50%    258876.500000       2.000000       0.510000      45.000000
# 75%    388314.750000       3.000000       0.710000      60.000000
# max    517753.000000       4.000000       1.000000      70.000000
#
#        num_reported_accidents  accident_risk
# count           517754.000000  517754.000000
# mean                 1.187970       0.352377
# std                  0.895961       0.166417
# min                  0.000000       0.000000
# 25%                  1.000000       0.230000
# 50%                  1.000000       0.340000
# 75%                  2.000000       0.460000
# max                  7.000000       1.000000

# %%
df_test.describe()
# Out:
#                   id      num_lanes      curvature    speed_limit  \
# count  172585.000000  172585.000000  172585.000000  172585.000000
# mean   604046.000000       2.494046       0.487263      46.102761
# std     49821.142441       1.119148       0.272343      15.787077
# min    517754.000000       1.000000       0.000000      25.000000
# 25%    560900.000000       1.000000       0.260000      35.000000
# 50%    604046.000000       2.000000       0.510000      45.000000
# 75%    647192.000000       3.000000       0.710000      60.000000
# max    690338.000000       4.000000       1.000000      70.000000
#
#        num_reported_accidents
# count           172585.000000
# mean                 1.186059
# std                  0.897161
# min                  0.000000
# 25%                  1.000000
# 50%                  1.000000
# 75%                  2.000000
# max                  7.000000

# %% [markdown]
#  Encode categorical variabless

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df_train['road_type'] = le.fit_transform(df_train['road_type'])
df_test['road_type'] = le.transform(df_test['road_type'])

# %%
df_train['road_type'].value_counts()
# Out:
# road_type
# 0    173672
# 1    172719
# 2    171363
# Name: count, dtype: int64

# %%
df_test['road_type'].value_counts()
# Out:
# road_type
# 0    58080
# 1    57409
# 2    57096
# Name: count, dtype: int64

# %%
le = LabelEncoder()
df_train['lighting'] = le.fit_transform(df_train['lighting'])
df_test['lighting'] = le.transform(df_test['lighting'])

# %%
df_train['lighting'].value_counts()
# Out:
# lighting
# 1    183826
# 0    178015
# 2    155913
# Name: count, dtype: int64

# %%
df_test['lighting'].value_counts()
# Out:
# lighting
# 1    61143
# 0    59397
# 2    52045
# Name: count, dtype: int64

# %%
le = LabelEncoder()
df_train['weather'] = le.fit_transform(df_train['weather'])
df_test['weather'] = le.transform(df_test['weather'])

# %%
df_train['weather'].value_counts()
# Out:
# weather
# 1    181463
# 0    179306
# 2    156985
# Name: count, dtype: int64

# %%
le = LabelEncoder()
df_train['road_signs_present'] = le.fit_transform(df_train['road_signs_present'])
df_test['road_signs_present'] = le.transform(df_test['road_signs_present'])

# %%
df_train['road_signs_present'].value_counts()
# Out:
# road_signs_present
# 0    259289
# 1    258465
# Name: count, dtype: int64

# %%
le = LabelEncoder()
df_train['public_road'] = le.fit_transform(df_train['public_road'])
df_test['public_road'] = le.transform(df_test['public_road'])

# %%
df_train['public_road'].value_counts()
# Out:
# public_road
# 1    260045
# 0    257709
# Name: count, dtype: int64

# %%
le = LabelEncoder()
df_train['time_of_day'] = le.fit_transform(df_train['time_of_day'])
df_test['time_of_day'] = le.transform(df_test['time_of_day'])

# %%
df_train['time_of_day'].value_counts()
# Out:
# time_of_day
# 2    173410
# 1    172837
# 0    171507
# Name: count, dtype: int64

# %%
le = LabelEncoder()
df_train['holiday'] = le.fit_transform(df_train['holiday'])
df_test['holiday'] = le.transform(df_test['holiday'])

# %%
df_train['holiday'].value_counts()
# Out:
# holiday
# 1    260688
# 0    257066
# Name: count, dtype: int64

# %%
le = LabelEncoder()
df_train['school_season'] = le.fit_transform(df_train['school_season'])
df_test['school_season'] = le.transform(df_test['school_season'])

# %%
df_train['school_season'].value_counts()
# Out:
# school_season
# 0    260164
# 1    257590
# Name: count, dtype: int64

# %%
df_train.head()
# Out:
#    id  road_type  num_lanes  curvature  speed_limit  lighting  weather  \
# 0   0          2          2       0.06           35         0        2
# 1   1          2          4       0.99           35         0        0
# 2   2          1          4       0.63           70         1        0
# 3   3          0          4       0.07           35         1        2
# 4   4          1          1       0.58           60         0        1
#
#    road_signs_present  public_road  time_of_day  holiday  school_season  \
# 0                   0            1            0        0              1
# 1                   1            0            1        1              1
# 2                   0            1            2        1              0
# 3                   1            1            2        0              0
# 4                   0            0            1        1              0
#
#    num_reported_accidents  accident_risk
# 0                       1           0.13
# 1                       0           0.35
# 2                       2           0.30
# 3                       1           0.21
# 4                       1           0.56

# %%
df_train.head()
# Out:
#    id  road_type  num_lanes  curvature  speed_limit  lighting  weather  \
# 0   0          2          2       0.06           35         0        2
# 1   1          2          4       0.99           35         0        0
# 2   2          1          4       0.63           70         1        0
# 3   3          0          4       0.07           35         1        2
# 4   4          1          1       0.58           60         0        1
#
#    road_signs_present  public_road  time_of_day  holiday  school_season  \
# 0                   0            1            0        0              1
# 1                   1            0            1        1              1
# 2                   0            1            2        1              0
# 3                   1            1            2        0              0
# 4                   0            0            1        1              0
#
#    num_reported_accidents  accident_risk
# 0                       1           0.13
# 1                       0           0.35
# 2                       2           0.30
# 3                       1           0.21
# 4                       1           0.56

# %% [markdown]
# data visualization

# %%
sns.countplot(x='accident_risk',data=df_train)
# Out:
# <Axes: xlabel='accident_risk', ylabel='count'>

# %%
sns.countplot(x='speed_limit',data=df_train)
# Out:
# <Axes: xlabel='speed_limit', ylabel='count'>

# %%
sns.countplot(x='num_lanes',data=df_train)
# Out:
# <Axes: xlabel='num_lanes', ylabel='count'>

# %%
sns.countplot(x='num_reported_accidents',data=df_train)
# Out:
# <Axes: xlabel='num_reported_accidents', ylabel='count'>

# %%
# List of categorical columns
categorical_columns = ['weather', 'accident_risk']  

# Set up the plotting grid
fig, axes = plt.subplots(nrows=len(categorical_columns), ncols=1, figsize=(40, 10 * len(categorical_columns)))
plt.subplots_adjust(hspace=0.5)  # Adjust space between plots

# Plot count plots for each categorical column
for i, column in enumerate(categorical_columns):
    sns.countplot(x=column, data=df_train, ax=axes[i])
    axes[i].set_title(f'Distribution of {column}')
    axes[i].set_xlabel(column)
    axes[i].set_ylabel('Count')

plt.show()

# %%
pair_plot = sns.pairplot(df_train)  
plt.show()

# %%
pair_plot = sns.pairplot(df_train)
pair_plot.savefig("pair_plot.png", dpi=300)  
plt.show()

# %%
def MultiBoxplot(df, num_cols, f_cols=4, filename=None):
    f_rows = np.ceil(len(num_cols) / f_cols).astype(int)
    fig, axes = plt.subplots(f_rows, f_cols, figsize=(25, 17))
    
    color = ['blue', 'green','yellow', 'red', 'purple', 'orange', 'black']  # Define some colors for the plots
    axes = axes.flatten()
    
    for i, col in enumerate(num_cols):
        sns.boxplot(x=df[col], ax=axes[i], color=color[i % len(color)])
        axes[i].set_title(f'{col} Distribution')
        axes[i].set_facecolor('lightgrey')
        axes[i].grid(color='black', linestyle='-', linewidth=0.25)
    
    # Remove any empty subplots
    if len(num_cols) % f_cols != 0:
        for i in range(f_cols - len(num_cols) % f_cols):
            fig.delaxes(axes[-i-1])

    plt.tight_layout()

    # Save the plot if filename is provided
    if filename:
        plt.savefig(filename, dpi=300)  # Save as PNG file with 300 dpi resolution

    plt.show()

# List of columns you want to plot
selected_columns = ['public_road', 'road_signs_present',  'lighting', 'weather',
 'id','road_type', 'time_of_day', 'holiday','school_season','num_reported_accidents',                
'num_lanes','curvature', 'speed_limit','accident_risk']

# Call the function with the selected columns
MultiBoxplot(df=df_train, num_cols=selected_columns, filename="box_plots.png")

# %%
def remove_outliers(df):
    numeric_cols = df[['public_road', 'road_signs_present',  'lighting', 'weather',
 'id','road_type', 'time_of_day', 'holiday','school_season','num_reported_accidents',                
'num_lanes','curvature', 'speed_limit']]

    # Calculate the first and third quartiles
    Q1 = numeric_cols.quantile(0.25)
    Q3 = numeric_cols.quantile(0.75)

    # Calculate the Interquartile Range (IQR)
    IQR = Q3 - Q1

    # Filter the data to remove rows with outliers
    df_filtered = df[~((numeric_cols < (Q1 - 1.5 * IQR)) | (numeric_cols > (Q3 + 1.5 * IQR))).any(axis=1)]

    return df_filtered

# Apply the function to the training data
df_train = remove_outliers(df_train)

# %%
def MultiBoxplot(df, num_cols, f_cols=4, filename=None):
    f_rows = np.ceil(len(num_cols) / f_cols).astype(int)
    fig, axes = plt.subplots(f_rows, f_cols, figsize=(25, 17))
    
    color = ['blue', 'green','yellow', 'red', 'purple', 'orange', 'black']  # Define some colors for the plots
    axes = axes.flatten()
    
    for i, col in enumerate(num_cols):
        sns.boxplot(x=df[col], ax=axes[i], color=color[i % len(color)])
        axes[i].set_title(f'{col} Distribution')
        axes[i].set_facecolor('lightgrey')
        axes[i].grid(color='black', linestyle='-', linewidth=0.25)
    
    # Remove any empty subplots
    if len(num_cols) % f_cols != 0:
        for i in range(f_cols - len(num_cols) % f_cols):
            fig.delaxes(axes[-i-1])

    plt.tight_layout()

    # Save the plot if filename is provided
    if filename:
        plt.savefig(filename, dpi=300)  # Save as PNG file with 300 dpi resolution

    plt.show()

# List of columns you want to plot
selected_columns = ['public_road', 'road_signs_present',  'lighting', 'weather',
 'id','road_type', 'time_of_day', 'holiday','school_season','num_reported_accidents',                
'num_lanes','curvature', 'speed_limit','accident_risk']

# Call the function with the selected columns
MultiBoxplot(df=df_train, num_cols=selected_columns, filename="box_plots.png")

# %%
corr_matrix = df_train.corr()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix, annot=True)
plt.savefig("correlation_heatmap.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# Features and Target variables

# %%
y = df_train.accident_risk

features = ['public_road', 'road_signs_present',  'lighting', 'weather','road_type',
'time_of_day', 'holiday','school_season','num_reported_accidents',                
'num_lanes','curvature', 'speed_limit']

X = df_train[features]
X.head()
# Out:
#    public_road  road_signs_present  lighting  weather  road_type  time_of_day  \
# 0            1                   0         0        2          2            0
# 1            0                   1         0        0          2            1
# 2            1                   0         1        0          1            2
# 3            1                   1         1        2          0            2
# 4            0                   0         0        1          1            1
#
#    holiday  school_season  num_reported_accidents  num_lanes  curvature  \
# 0        0              1                       1          2       0.06
# 1        1              1                       0          4       0.99
# 2        1              0                       2          4       0.63
# 3        0              0                       1          4       0.07
# 4        1              0                       1          1       0.58
#
#    speed_limit
# 0           35
# 1           35
# 2           70
# 3           35
# 4           60

# %% [markdown]
# Data Encoding

# %%
#test train split 
from sklearn.model_selection import train_test_split
# Split into validation and training data
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=1)

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train_scaled = sc.fit_transform(train_X)
X_test_scaled = sc.transform(val_X)

# %%
X_train_scaled
# Out:
# array([[ 0.99648069, -0.99750782, -1.18958216, ...,  1.34744934,
#         -0.616583  ,  1.51959578],
#        [-1.00353174, -0.99750782,  1.30725392, ..., -0.43811579,
#         -0.43294344, -1.33495618],
#        [ 0.99648069, -0.99750782,  0.05883588, ..., -1.33089836,
#          0.52198225, -1.33495618],
#        ...,
#        [ 0.99648069, -0.99750782,  0.05883588, ..., -0.43811579,
#          0.52198225,  1.51959578],
#        [ 0.99648069, -0.99750782,  1.30725392, ...,  0.45466678,
#         -0.21257598, -0.7006113 ],
#        [ 0.99648069, -0.99750782,  1.30725392, ...,  0.45466678,
#          0.77907763,  0.8852509 ]])

# %%
X_test_scaled
# Out:
# array([[ 0.99648069, -0.99750782,  0.05883588, ...,  1.34744934,
#          0.00779149, -0.7006113 ],
#        [-1.00353174,  1.00249841,  0.05883588, ..., -0.43811579,
#          0.99944509, -0.06626642],
#        [-1.00353174,  1.00249841,  1.30725392, ...,  0.45466678,
#         -0.57985509,  0.8852509 ],
#        ...,
#        [-1.00353174, -0.99750782,  1.30725392, ...,  0.45466678,
#          0.66889389, -0.7006113 ],
#        [ 0.99648069,  1.00249841,  1.30725392, ..., -1.33089836,
#          1.66054749,  1.51959578],
#        [ 0.99648069,  1.00249841, -1.18958216, ..., -0.43811579,
#         -1.46132495, -0.7006113 ]])

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
import lightgbm
import catboost
import joblib

# %%
#Define a list of models to train and compare
models = [
    ('Linear Regression', LinearRegression()),
    ('Ridge Regression', Ridge()),
    ('Lasso Regression', Lasso()),
    ('Decision Tree', DecisionTreeRegressor(random_state=42)),
    ('Random Forest', RandomForestRegressor(random_state=42)),
    ("XGB" , XGBRegressor()),
    ("CAT" , catboost.CatBoostRegressor(verbose=0)),
    ("LGBM" , lightgbm.LGBMRegressor(verbose=0))
]

# Train and evaluate each model
for name, model in models:
    model.fit(train_X, train_y)
    y_pred = model.predict(val_X)
    mse = mean_squared_error(val_y, y_pred)
    r2 = r2_score(val_y, y_pred)
    print(f'{name}: MSE = {mse:.6f}, R2 = {r2:.6f}')
# Out:
# Linear Regression: MSE = 0.007782, R2 = 0.711614
# Ridge Regression: MSE = 0.007782, R2 = 0.711614
# Lasso Regression: MSE = 0.026053, R2 = 0.034515
# Decision Tree: MSE = 0.006910, R2 = 0.743924
# Random Forest: MSE = 0.003523, R2 = 0.869438
# XGB: MSE = 0.003152, R2 = 0.883205
# 992:	learn: 0.0553665	total: 28.5s	remaining: 201ms
# 993:	learn: 0.0553660	total: 28.5s	remaining: 172ms
# 994:	learn: 0.0553655	total: 28.5s	remaining: 143ms
# 995:	learn: 0.0553648	total: 28.6s	remaining: 115ms
# 996:	learn: 0.0553643	total: 28.6s	remaining: 86.1ms
# 997:	learn: 0.0553638	total: 28.6s	remaining: 57.4ms
# 998:	learn: 0.0553633	total: 28.7s	remaining: 28.7ms
# 999:	learn: 0.0553629	total: 28.7s	remaining: 0us
# 0.003146992143961192
# 0.8833784030133265
# Validation MAE for CatBoostRegressor Model: 0

# %%
# print the top few validation predictions

print(cbr.predict(val_X.head()))
# print the top few actual ages from validation data
print(val_y.head())
# Out:
# [0.24857503 0.34054287 0.49182353 0.49382713 0.44947871]
# 202067    0.22
# 281156    0.23
# 419967    0.47
# 463311    0.48
# 227215    0.41
# Name: accident_risk, dtype: float64

# %%
val_mae = cbr.predict(val_X)

print( mean_absolute_error(val_y, y_pred))
# Out:
# 0.043573657114025506

# %% [markdown]
# Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
# parameter grid for CatBoost
param_grid = {
    'iterations': [100, 200, 300],  # Number of boosting iterations
    'depth': [6, 8, 10],            # Depth of trees
    'learning_rate': [0.01, 0.1, 0.2],  # Learning rate
    'l2_leaf_reg': [1, 3, 5]        # Regularization coefficient
}

# %%
# Create CatBoostRegressor model
model = CatBoostRegressor(
    early_stopping_rounds=50,  # Stop early if no improvement
    thread_count=-1,           # Use all CPU cores
    logging_level='Silent',    # Suppress output during training
    loss_function='RMSE'       # Regression metric
)

# %%
# Set up GridSearchCV
grid_search = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    scoring='neg_mean_squared_error',  # Use MSE to evaluate
    cv=3,                              # 3-fold cross-validation
    n_jobs=-1                           # Parallelize across all cores
)

# %%
# Fit on training data
grid_search.fit(train_X, train_y)
# Out:
# GridSearchCV(cv=3,
#              estimator=<catboost.core.CatBoostRegressor object at 0x781e7c76d370>,
#              n_jobs=-1,
#              param_grid={'depth': [6, 8, 10], 'iterations': [100, 200, 300],
#                          'l2_leaf_reg': [1, 3, 5],
#                          'learning_rate': [0.01, 0.1, 0.2]},
#              scoring='neg_mean_squared_error')

# %%
#Get the best model and best hyperparameters
best_model = grid_search.best_estimator_
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)
# Out:
# Best Hyperparameters: {'depth': 8, 'iterations': 300, 'l2_leaf_reg': 3, 'learning_rate': 0.1}

# %%
# print the top few validation predictions

print(best_model.predict(val_X.head()))
# print the top few actual ages from validation data
print(val_y.head())
# Out:
# [0.24604492 0.34249096 0.48405016 0.49375393 0.4469932 ]
# 202067    0.22
# 281156    0.23
# 419967    0.47
# 463311    0.48
# 227215    0.41
# Name: accident_risk, dtype: float64

# %%
val_mae = best_model.predict(val_X)

print( mean_absolute_error(val_y, y_pred))
# Out:
# 0.043573657114025506

# %%
test_X = df_test[features]
test_preds = best_model.predict(test_X)


output = pd.DataFrame({'id': df_test.id,
                       'accident_risk': test_preds})
output.to_csv('submission9.csv', index=False)
